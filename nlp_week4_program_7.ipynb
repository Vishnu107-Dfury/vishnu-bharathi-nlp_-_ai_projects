# %%
import nltk 
from nltk import word_tokenize,pos_tag,ne_chunk
from nltk.tree import Tree

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\vishnu bharathi .
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vishnu bharathi .
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\vishnu
# [nltk_data]     bharathi . B\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to C:\Users\vishnu bharathi .
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
#sample text
text="Apple Inc. was foundeed by Steve Jobs in Cupertino on April 1, 1976"

# %%
#tokenization
tokens=word_tokenize(text)

# %%
#pos tagging
pos_tags=pos_tag(tokens)

# %%
#named entity recognition
ner_tree=ne_chunk(pos_tags)

# %%
#Display named entity
print("Named Entities:\n")
for subtree in ner_tree:
    if isinstance(subtree,Tree):
        entity=" ".join([word for word,tag in subtree.leaves()])
        label=subtree.label()
        print(entity, "->",label)
# Out:
# Named Entities:
#
# Apple -> PERSON
# Inc. -> ORGANIZATION
# Steve Jobs -> PERSON
# Cupertino -> GPE
